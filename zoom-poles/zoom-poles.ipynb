# %% [markdown]
# # Studying the poles of the damped Traub's method
# Here we study the poles of the damped Traub's method applied on cubic polynomials.

# %%
from utils import *

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (-2,4), (-3,3), 1024,1024,roots, colors, delta = 1)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (0.26,0.6), (-0.15,0.15), 1024,1024,roots, colors, delta = 0.01,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (0.2,0.6), (-0.18,0.18), 1024,1024,roots, colors, delta = 0.1,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (0.15,0.6), (-0.19,0.19), 1024,1024,roots, colors, delta = 0.3,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (0.1,0.7), (-0.25,0.25), 1024,1024,roots, colors, delta = 0.5,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (0,0.8), (-0.35,0.35), 1024,1024,roots, colors, delta = 0.7,print_free_fixed=True)

# %%
def f(z):
    return z * (z - 1) * (z - 2)


def der_f(z):
    return 3 * z ** 2 - 6 * z + 2


roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (-0.02, 1), (-0.43, 0.43), 1024, 1024, roots, colors, delta=0.99,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-2)

def der_f(z):
    return 3*z**2 - 6*z + 2

roots = [0, 1, 2]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_2left(f, der_f, (0.5,0.58), (-0.03,0.03), 1024,1024,roots, colors, delta = 0.99,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (-2,7), (-3,3), 1024,1024,roots, colors, delta = 1)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (0.4,0.55), (-0.07,0.07), 1024,1024,roots, colors, delta = 0.01,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (0.3,0.65), (-0.1,0.1), 1024,1024,roots, colors, delta = 0.1,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (0.2,0.75), (-0.12,0.12), 1024,1024,roots, colors, delta = 0.3,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (0.1,0.85), (-0.15,0.15), 1024,1024,roots, colors, delta = 0.5,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (0,0.92), (-0.15,0.15), 1024,1024,roots, colors, delta = 0.7,print_free_fixed=True)

# %%
def f(z):
    return z*(z-1)*(z-6)

def der_f(z):
    return 3*z**2 - 14*z + 6

roots = [0, 1, 6]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_6left(f, der_f, (-0.01,1.01), (-0.15,0.15), 1024,1024,roots, colors, delta = 0.99,print_free_fixed=True)

# %%
def f(z):
    return z * (z - 1) * (z - (1 + 1j))


def der_f(z):
    return 3 * z ** 2 - 2*(2+1j) * z + (1+1j)


roots = [0, 1, 1 + 1j]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_1ileft(f, der_f, (-3, 3), (-1.5, 4.5), 1024, 1024, roots, colors, delta=1)

# %%
def f(z):
    return z * (z - 1) * (z - (1 + 1j))


def der_f(z):
    return 3 * z ** 2 - 2*(2+1j) * z + (1+1j)


roots = [0, 1, 1 + 1j]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_1ileft(f, der_f, (0.32, 0.6), (-0.1, 0.2), 1024, 1024, roots, colors, delta=0.01, print_free_fixed=True)

# %%
def f(z):
    return z * (z - 1) * (z - (1 + 1j))


def der_f(z):
    return 3 * z ** 2 - 2*(2+1j) * z + (1+1j)


roots = [0, 1, 1 + 1j]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_1ileft(f, der_f, (0.25, 0.64), (-0.1, 0.3), 1024, 1024, roots, colors, delta=0.1, print_free_fixed=True)

# %%
def f(z):
    return z * (z - 1) * (z - (1 + 1j))


def der_f(z):
    return 3 * z ** 2 - 2*(2+1j) * z + (1+1j)


roots = [0, 1, 1 + 1j]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_1ileft(f, der_f, (0, 1), (-0.1, 0.55), 1024, 1024, roots, colors, delta=0.5, print_free_fixed=True)

# %%
def f(z):
    return z * (z - 1) * (z - (1 + 1j))


def der_f(z):
    return 3 * z ** 2 - 2*(2+1j) * z + (1+1j)


roots = [0, 1, 1 + 1j]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_1ileft(f, der_f, (0, 1), (-0.1, 0.55), 1024, 1024, roots, colors, delta=0.7, print_free_fixed=True)

# %%
def f(z):
    return z * (z - 1) * (z - (1 + 1j))


def der_f(z):
    return 3 * z ** 2 - 2*(2+1j) * z + (1+1j)


roots = [0, 1, 1 + 1j]
colors = [
    [255, 0, 0],  # Red
    [0, 255, 0],  # Green
    [0, 255, 255],  # Blue
]

plot_colored_damped_traub_1ileft(f, der_f, (0, 1), (-0.1, 0.55), 1024, 1024, roots, colors, delta=0.99, print_free_fixed=True)
