# %% [markdown]
# # Parameter plane of damped Traub's method
# Here we plot the parameter plane of the method when applied to the polynomials $p(z)=(z-\alpha_1)(z-\alpha_2)$. In this case, the parameter plane is well-defined, since there is only one free critical point.

# %%
from utils import *
plot_parameter_plane()
